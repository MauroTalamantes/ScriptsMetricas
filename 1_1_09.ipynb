# %% [markdown]
# # Métrica 1.1.09: "Validar estructura de CURP (pareja)"

# %%
import re
import urllib.parse
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure, OperationFailure
import unicodedata
import traceback
# Asumimos que tienes un archivo config.py con tus variables de conexión
from config import MONGO_URI, DB_NAME, SOURCE_COLLECTION_NAME, METRICS_COLLECTION_NAME

# --- 1. CONFIGURACIÓN BÁSICA ---
METRIC_ID = "1_1_09_CURP_PAREJA_ESTRUCTURA"
SOURCE_COLLECTION_NAME = "all_data_20251021"

# --- 2. LÓGICA PURA DE LA MÉTRICA (Reutilizada de 1.1.01) ---

def validar_curp_estructura(curp: str) -> bool:
    """
    Valida la estructura de una CURP según la métrica 1.1.01/1.1.09,
    incluyendo la validación de las 32 entidades federativas.
    """
    if not isinstance(curp, str):
        return False
        
    # Esta es la expresión regular que implementa TODOS tus puntos.
    curp_regex = (
        "^[A-Z][AEIOU][A-Z]{2}"  # 4 letras, 2da es vocal
        "[0-9]{2}(0[1-9]|1[0-2])(0[1-9]|[12][0-9]|3[01])"  # Fecha aammdd
        "[HM]"  # Sexo H o M
        # Abreviación de Entidad Federativa (32 estados + Nacido Extranjero)
        "(AS|BC|BS|CC|CS|CH|CL|CM|DF|DG|GT|GR|HG|JC|MC|MN|MS|NT|NL|OC|PL|QT|QR|SP|SL|SR|TC|TS|TL|VZ|YN|ZS|NE)"
        "[B-DF-HJ-NP-TV-Z]{3}"  # 3 Consonantes
        "[A-Z0-9]"  # Alfanumérico (Homoclave)
        "[0-9]$"  # Numérico (Dígito verificador)
    )
    
    if re.match(curp_regex, curp):
        return True
    else:
        return False

# --- 3. EL FLUJO DEL WORKER (PROCESAMIENTO POR LOTES) ---
def procesar_todas_las_declaraciones_curp_pareja():
    """
    Procesa TODAS las declaraciones para la Métrica 1.1.09
    """
    client = None
    # Contadores
    total_documentos = 0
    cumple = 0
    no_cumple = 0
    sin_dato = 0
    na = 0 # No Aplica (para quienes no tienen pareja)
    
    try:
        # --- A. CONECTAR A LA BASE DE DATOS ---
        print(f"\nConectando a MongoDB en {DB_NAME}...")
        client = MongoClient(MONGO_URI, serverSelectionTimeoutMS=5000)
        client.admin.command('ping') 
        db = client[DB_NAME]
        source_collection = db[SOURCE_COLLECTION_NAME]
        target_collection = db[METRICS_COLLECTION_NAME]
        
        print("¡Conexión exitosa!")
        print(f"--- INICIANDO PROCESAMIENTO (Métrica 1.1.09 - Estructura CURP Pareja) ---")

        # Proyección optimizada para traer el 'id' y la sección 'datosPareja'
        proyeccion = {
            "_id": 1,
            "id": 1,
            "declaracion.situacionPatrimonial.datosPareja": 1 
        }
        
        for doc in source_collection.find({}, proyeccion):
            total_documentos += 1
            original_id = doc["_id"]
            string_id = doc.get("id", "N/D")
            
            curp_pareja = None
            resultado_metrica = "SIN_DATO" # Valor por defecto
            
            try:
                # Navegación segura
                datos_pareja = doc.get("declaracion", {}).get("situacionPatrimonial", {}).get("datosPareja")

                # --- Lógica de la Métrica ---
                if not isinstance(datos_pareja, dict):
                    # No existe la sección 'datosPareja'
                    resultado_metrica = "SIN_DATO"
                
                elif datos_pareja.get("ninguno") is True:
                    # El declarante marcó "Ninguno" en la sección de pareja
                    resultado_metrica = "N/A"
                
                else:
                    # El declarante SÍ tiene pareja, buscamos el CURP
                    curp_pareja = datos_pareja.get("curp")
                    
                    if curp_pareja and curp_pareja.strip() != "":
                        if validar_curp_estructura(curp_pareja):
                            resultado_metrica = "CUMPLE"
                        else:
                            resultado_metrica = "NO_CUMPLE"
                    else:
                        # Tiene pareja pero no proporcionó el CURP
                        resultado_metrica = "SIN_DATO"

            except AttributeError:
                resultado_metrica = "SIN_DATO" # Ocurrió un error leyendo la estructura
            
            # Actualizamos contadores
            if resultado_metrica == "CUMPLE": cumple += 1
            elif resultado_metrica == "NO_CUMPLE": no_cumple += 1
            elif resultado_metrica == "N/A": na += 1
            else: sin_dato += 1 # SIN_DATO

            # --- CONSERVAMOS TU SALIDA DE CONSOLA ---
            print(f"\nProcesando Documento ID: {original_id} (id: {string_id})")
            print("--- RESULTADO DEL ANÁLISIS ---")
            print(f"  > CURP Pareja: '{curp_pareja}'")
            print(f"  > Resultado de la Métrica: {resultado_metrica}")
            print("---------------------------------")

            # --- E. GUARDAR RESULTADO EN LA COLECCIÓN 'metricas' ---
            filtro = { "_id": original_id }
            actualizacion = { "$set": { METRIC_ID: resultado_metrica } }
            target_collection.update_one(filtro, actualizacion, upsert=True)
            print(f"¡Resultado guardado/actualizado en 'metricas' para el ID: {original_id}!")

        print("\n--- PROCESAMIENTO POR LOTES FINALIZADO ---")
        print("Resumen (Métrica 1.1.09):")
        print(f"  > Documentos Totales Procesados: {total_documentos}")
        print(f"  > Métrica 'CUMPLE': {cumple}")
        print(f"  > Métrica 'NO_CUMPLE': {no_cumple}")
        print(f"  > Métrica 'N/A' (Sin pareja declarada): {na}")
        print(f"  > Métrica 'SIN_DATO': {sin_dato}")

    except ConnectionFailure: print("Error: No se pudo conectar a la base de datos.")
    except OperationFailure as e: print(f"Error en la operación de la base de datos: {e.details}")
    except Exception as e:
        print(f"Ocurrió un error inesperado: {e}")
        traceback.print_exc()
    finally:
        if client: client.close(); print("Conexión cerrada.")

# --- 4. EJECUTAR EL SCRIPT ---
if __name__ == "__main__":
    procesar_todas_las_declaraciones_curp_pareja()
# Out:
# Conectando a MongoDB en sistema1...
# ¡Conexión exitosa!
# --- INICIANDO PROCESAMIENTO (Métrica 1.1.09 - Estructura CURP Pareja) ---
#
# Procesando Documento ID: 68f81b8800535f910a29f694 (id: 194916)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f694!
#
# Procesando Documento ID: 68f81b8800535f910a29f695 (id: 59837)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f695!
#
# Procesando Documento ID: 68f81b8800535f910a29f696 (id: 31074)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f696!
#
# Procesando Documento ID: 68f81b8800535f910a29f697 (id: 62854)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f697!
#
# Procesando Documento ID: 68f81b8800535f910a29f698 (id: 231941)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f698!
#
# Procesando Documento ID: 68f81b8800535f910a29f699 (id: 207021)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f699!
#
# Procesando Documento ID: 68f81b8800535f910a29f69a (id: 232548)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f69a!
#
# Procesando Documento ID: 68f81b8800535f910a29f69b (id: 39351)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f69b!
#
# Procesando Documento ID: 68f81b8800535f910a29f69c (id: 184287)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29

# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f70b!
#
# Procesando Documento ID: 68f81b8800535f910a29f70c (id: 28)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f70c!
#
# Procesando Documento ID: 68f81b8800535f910a29f70d (id: 4316)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f70d!
#
# Procesando Documento ID: 68f81b8800535f910a29f70e (id: 216295)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f70e!
#
# Procesando Documento ID: 68f81b8800535f910a29f70f (id: 27475)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f70f!
#
# Procesando Documento ID: 68f81b8800535f910a29f710 (id: 29055)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f710!
#
# Procesando Documento ID: 68f81b8800535f910a29f711 (id: 91976)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f711!
#
# Procesando Documento ID: 68f81b8800535f910a29f712 (id: 135624)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f712!
#
# Procesando Documento ID: 68f81b8800535f910a29f713 (id: 233271)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f713!
#
# Procesando Documento ID: 68f81b8800535f910a29f714 (id: 96495)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f714!
#
# Procesando Documento ID: 68f81b8800535f910a29f715 (id: 26693)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f715!
#
# Procesando Documento ID: 68f81b8800535f910a29f716 (id: 237290)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f716!
#
# Procesando Documento ID: 68f81b8800535f910a29f717 (id: 240193)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f717!
#
# Procesando Documento ID: 68f81b8800535f910a29f718 (id: 144996)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f718!
#
# Procesando Documento ID: 68f81b8800535f910a29f719 (id: 76050)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f719!
#
# Procesando Documento ID: 68f81b8800535f910a29f71a (id: 110205)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f71a!
#
# Procesando Documento ID: 68f81b8800535f910a29f71b (id: 206041)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f71b!
#
# Procesando Documento ID: 68f81b8800535f910a29f71c (id: 67202)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f71c!
#
# Procesando Documento ID: 68f81b8800535f910a29f71d (id: 150428)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f71d!
#
# Procesando Documento ID: 68f81b8800535f910a29f71e (id: 35987)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f71e!
#
# Procesando Documento ID: 68f81b8800535f910a29f71f (id: 210497)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f71f!
#
# Procesando Documento ID: 68f81b8800535f910a29f720 (id: 231995)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f720!
#
# Procesando Documento ID: 68f81b8800535f910a29f721 (id: 110214)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f721!
#
# Procesando Documento ID: 68f81b8800535f910a29f722 (id: 34228)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f722!
#
# Procesando Documento ID: 68f81b8800535f910a29f723 (id: 25833)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f723!
#
# Procesando Documento ID: 68f81b8800535f910a29f724 (id: 221883)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f724!
#
# Procesando Documento ID: 68f81b8800535f910a29f725 (id: 43587)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f725!
#
# Procesando Documento ID: 68f81b8800535f910a29f726 (id: 136571)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f726!
#
# Procesando Documento ID: 68f81b8800535f910a29f727 (id: 8859)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f727!
#
# Procesando Documento ID: 68f81b8800535f910a29f728 (id: 152595)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f728!
#
# Procesando Documento ID: 68f81b8800535f910a29f729 (id: 96745)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f729!
#
# Procesando Documento ID: 68f81b8800535f910a29f72a (id: 54361)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f72a!
#
# Procesando Documento ID: 68f81b8800535f910a29f72b (id: 2836)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f72b!
#
# Procesando Documento ID: 68f81b8800535f910a29f72c (id: 1568)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f72c!
#
# Procesando Documento ID: 68f81b8800535f910a29f72d (id: 5550)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f72d!
#
# Procesando Documento ID: 68f81b8800535f910a29f72e (id: 201568)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f72e!
#
# Procesando Documento ID: 68f81b8800535f910a29f72f (id: 218843)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f72f!
#
# Procesando Documento ID: 68f81b8800535f910a29f730 (id: 60414)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f730!
#
# Procesando Documento ID: 68f81b8800535f910a29f731 (id: 113426)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f731!
#
# Procesando Documento ID: 68f81b8800535f910a29f732 (id: 109940)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f732!
#
# Procesando Documento ID: 68f81b8800535f910a29f733 (id: 86652)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f733!
#
# Procesando Documento ID: 68f81b8800535f910a29f734 (id: 11205)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f734!
#
# Procesando Documento ID: 68f81b8800535f910a29f735 (id: 136191)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f735!
#
# Procesando Documento ID: 68f81b8800535f910a29f736 (id: 103835)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f736!
#
# Procesando Documento ID: 68f81b8800535f910a29f737 (id: 194179)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f737!
#
# Procesando Documento ID: 68f81b8800535f910a29f738 (id: 162003)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f738!
#
# Procesando Documento ID: 68f81b8800535f910a29f739 (id: 14012)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f739!
#
# Procesando Documento ID: 68f81b8800535f910a29f73a (id: 220141)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f73a!
#
# Procesando Documento ID: 68f81b8800535f910a29f73b (id: 194178)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f73b!
#
# Procesando Documento ID: 68f81b8800535f910a29f73c (id: 73157)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f73c!
#
# Procesando Documento ID: 68f81b8800535f910a29f73d (id: 134728)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f73d!
#
# Procesando Documento ID: 68f81b8800535f910a29f73e (id: 172377)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f73e!
#
# Procesando Documento ID: 68f81b8800535f910a29f73f (id: 87768)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f73f!
#
# Procesando Documento ID: 68f81b8800535f910a29f740 (id: 122985)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f740!
#
# Procesando Documento ID: 68f81b8800535f910a29f741 (id: 126075)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f741!
#
# Procesando Documento ID: 68f81b8800535f910a29f742 (id: 188559)
# --- RESULTADO DEL ANÁLISIS ---
# ...
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f893!
#
# Procesando Documento ID: 68f81b8800535f910a29f894 (id: 176103)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f894!
#
# Procesando Documento ID: 68f81b8800535f910a29f895 (id: 75547)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f895!
#
# Procesando Documento ID: 68f81b8800535f910a29f896 (id: 134822)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f896!
#
# Procesando Documento ID: 68f81b8800535f910a29f897 (id: 94231)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f897!
#
# Procesando Documento ID: 68f81b8800535f910a29f898 (id: 208646)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f898!
#
# Procesando Documento ID: 68f81b8800535f910a29f899 (id: 137791)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f899!
#
# Procesando Documento ID: 68f81b8800535f910a29f89a (id: 208982)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f89a!
#
# Procesando Documento ID: 68f81b8800535f910a29f89b (id: 222734)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f89b!
#
# Procesando Documento ID: 68f81b8800535f910a29f89c (id: 165299)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f89c!
#
# Procesando Documento ID: 68f81b8800535f910a29f89d (id: 163985)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f89d!
#
# Procesando Documento ID: 68f81b8800535f910a29f89e (id: 76727)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f89e!
#
# Procesando Documento ID: 68f81b8800535f910a29f89f (id: 208082)
# --- RESULTADO DEL ANÁLISIS ---
#   > CURP Pareja: 'None'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# Conexión cerrada.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 147
#     145 # --- 4. EJECUTAR EL SCRIPT ---
#     146 if __name__ == "__main__":
# --> 147     procesar_todas_las_declaraciones_curp_pareja()
#
# Cell In[1], line 126, in procesar_todas_las_declaraciones_curp_pareja()
#     124     filtro = { "_id": original_id }
#     125     actualizacion = { "$set": { METRIC_ID: resultado_metrica } }
# --> 126     target_collection.update_one(filtro, actualizacion, upsert=True)
#     127     print(f"¡Resultado guardado/actualizado en 'metricas' para el ID: {original_id}!")
#     129 print("\n--- PROCESAMIENTO POR LOTES FINALIZADO ---")
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\collection.py:1336, in Collection.update_one(self, filter, update, upsert, bypass_document_validation, collation, array_filters, hint, session, let, sort, comment)
#    1332 common.validate_list_or_none("array_filters", array_filters)
#    1334 write_concern = self._write_concern_for(session)
#    1335 return UpdateResult(
# -> 1336     self._update_retryable(
#    1337         filter,
#    1338         update,
#    1339         _Op.UPDATE,
#    1340         upsert,
#    1341         write_concern=write_concern,
#    1342         bypass_doc_val=bypass_document_validation,
#    1343         collation=collation,
#    1344         array_filters=array_filters,
#    1345         hint=hint,
#    1346         session=session,
#    1347         let=let,
#    1348         sort=sort,
#    1349         comment=comment,
#    1350     ),
#    1351     write_concern.acknowledged,
#    1352 )
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\collection.py:1118, in Collection._update_retryable(self, criteria, document, operation, upsert, multi, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, hint, session, let, sort, comment)
#    1095 def _update(
#    1096     session: Optional[ClientSession], conn: Connection, retryable_write: bool
#    1097 ) -> Optional[Mapping[str, Any]]:
#    1098     return self._update(
#    1099         conn,
#    1100         criteria,
#    (...)
#    1115         comment=comment,
#    1116     )
# -> 1118 return self._database.client._retryable_write(
#    1119     (write_concern or self.write_concern).acknowledged and not multi,
#    1120     _update,
#    1121     session,
#    1122     operation,
#    1123 )
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2082, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2068 """Execute an operation with consecutive retries if possible
#    2069
#    2070 Returns func()'s return value on success. On error retries the same
#    (...)
#    2079 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2080 """
#    2081 with self._tmp_session(session) as s:
# -> 2082     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1968, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1963 # Ensure that the options supports retry_writes and there is a valid session not in
#    1964 # transaction, otherwise, we will not support retry behavior for this txn.
#    1965 retryable = bool(
#    1966     retryable and self.options.retry_writes and session and not session.in_transaction
#    1967 )
# -> 1968 return self._retry_internal(
#    1969     func=func,
#    1970     session=session,
#    1971     bulk=bulk,
#    1972     operation=operation,
#    1973     retryable=retryable,
#    1974     operation_id=operation_id,
#    1975 )
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)
#    1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)
#    2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2765, in _ClientConnectionRetryable.run(self)
#    2763 self._check_last_error(check_csot=True)
#    2764 try:
# -> 2765     return self._read() if self._is_read else self._write()
#    2766 except ServerSelectionTimeoutError:
#    2767     # The application may think the write was never attempted
#    2768     # if we raise ServerSelectionTimeoutError on the retry
#    2769     # attempt. Raise the original exception instead.
#    2770     self._check_last_error()
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2897, in _ClientConnectionRetryable._write(self)
#    2889         if self._retrying:
#    2890             _debug_log(
#    2891                 _COMMAND_LOGGER,
#    2892                 message=f"Retrying write attempt number {self._attempt_number}",
#    (...)
#    2895                 operationId=self._operation_id,
#    2896             )
# -> 2897         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2898 except PyMongoError as exc:
#    2899     if not self._retryable:
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\collection.py:1098, in Collection._update_retryable.<locals>._update(session, conn, retryable_write)
#    1095 def _update(
#    1096     session: Optional[ClientSession], conn: Connection, retryable_write: bool
#    1097 ) -> Optional[Mapping[str, Any]]:
# -> 1098     return self._update(
#    1099         conn,
#    1100         criteria,
#    1101         document,
#    1102         upsert=upsert,
#    1103         multi=multi,
#    1104         write_concern=write_concern,
#    1105         op_id=op_id,
#    1106         ordered=ordered,
#    1107         bypass_doc_val=bypass_doc_val,
#    1108         collation=collation,
#    1109         array_filters=array_filters,
#    1110         hint=hint,
#    1111         session=session,
#    1112         retryable_write=retryable_write,
#    1113         let=let,
#    1114         sort=sort,
#    1115         comment=comment,
#    1116     )
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\collection.py:1049, in Collection._update(self, conn, criteria, document, upsert, multi, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, hint, session, retryable_write, let, sort, comment)
#    1044     command["bypassDocumentValidation"] = bypass_doc_val
#    1046 # The command result has to be published for APM unmodified
#    1047 # so we make a shallow copy here before adding updatedExisting.
#    1048 result = (
# -> 1049     conn.command(
#    1050         self._database.name,
#    1051         command,
#    1052         write_concern=write_concern,
#    1053         codec_options=self._write_response_codec_options,
#    1054         session=session,
#    1055         client=self._database.client,
#    1056         retryable_write=retryable_write,
#    1057     )
#    1058 ).copy()
#    1059 _check_write_command_response(result)
#    1060 # Add the updatedExisting field for compatibility.
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:441, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     439 # Catch socket.error, KeyboardInterrupt, CancelledError, etc. and close ourselves.
#     440 except BaseException as error:
# --> 441     self._raise_connection_failure(error)
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:413, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     411     self._raise_if_not_writable(unacknowledged)
#     412 try:
# --> 413     return command(
#     414         self,
#     415         dbname,
#     416         spec,
#     417         self.is_mongos,
#     418         read_preference,
#     419         codec_options,  # type: ignore[arg-type]
#     420         session,
#     421         client,
#     422         check,
#     423         allowable_errors,
#     424         self.address,
#     425         listeners,
#     426         self.max_bson_size,
#     427         read_concern,
#     428         parse_write_concern_error=parse_write_concern_error,
#     429         collation=collation,
#     430         compression_ctx=self.compression_context,
#     431         use_op_msg=self.op_msg_enabled,
#     432         unacknowledged=unacknowledged,
#     433         user_fields=user_fields,
#     434         exhaust_allowed=exhaust_allowed,
#     435         write_concern=write_concern,
#     436     )
#     437 except (OperationFailure, NotPrimaryError):
#     438     raise
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\network.py:198, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     196     response_doc: _DocumentOut = {"ok": 1}
#     197 else:
# --> 198     reply = receive_message(conn, request_id)
#     199     conn.more_to_come = reply.more_to_come
#     200     unpacked_docs = reply.unpack_response(
#     201         codec_options=codec_options, user_fields=user_fields
#     202     )
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\network_layer.py:759, in receive_message(conn, request_id, max_message_size)
#     757         deadline = None
#     758 # Ignore the response's request id.
# --> 759 length, _, response_to, op_code = _UNPACK_HEADER(receive_data(conn, 16, deadline))
#     760 # No request_id for exhaust cursor "getMore".
#     761 if request_id is not None:
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\network_layer.py:343, in receive_data(conn, length, deadline)
#     339 try:
#     340     # Use the legacy wait_for_read cancellation approach on PyPy due to PYTHON-5011.
#     341     # also use it on Windows due to PYTHON-5405
#     342     if _PYPY or _WINDOWS:
# --> 343         wait_for_read(conn, deadline)
#     344         if _csot.get_timeout() and deadline is not None:
#     345             conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\network_layer.py:316, in wait_for_read(conn, deadline)
#     314     else:
#     315         timeout = _POLL_TIMEOUT
# --> 316     readable = conn.socket_checker.select(sock, read=True, timeout=timeout)
#     317 if conn.cancel_context.cancelled:
#     318     raise _OperationCancelled("operation cancelled")
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\socket_checker.py:77, in SocketChecker.select(self, sock, read, write, timeout)
#      75 rlist = [sock] if read else []
#      76 wlist = [sock] if write else []
# ---> 77 res = select.select(rlist, wlist, [sock], timeout)
#      78 # select returns a 3-tuple of lists of objects that are
#      79 # ready: subsets of the first three arguments. Return
#      80 # True if any of the lists are not empty.
#      81 return any(res)
#
# KeyboardInterrupt:
