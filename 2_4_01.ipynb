# %% [markdown]
# # Métrica 2_4_01 — Desviaciones en el ingreso según nivel jerárquico
#
# | Escenario                                                      | Condición      | Resultado        |
# | -------------------------------------------------------------- | -------------- | ---------------- |
# | Falta de datos o no obligatorio                                | —              | ⚪ **SIN_DATO**   |
# | Ingreso dentro del rango intercuartílico (Q1–Q3) para su nivel | ✅              | 🟢 **CUMPLE**    |
# | Ingreso fuera de ese rango                                     | ❌              | 🔴 **NO_CUMPLE** |
# | Sin referencia para ese nivel (pocos datos en el grupo)        | ⚪ **SIN_DATO** |                  |

# %%
import traceback
import numpy as np
import pandas as pd
from pymongo import MongoClient, UpdateOne
from config import MONGO_URI, DB_NAME, SOURCE_COLLECTION_NAME, METRICS_COLLECTION_NAME

METRIC_ID = "2_4_01_DESVIACION_INGRESO_NIVEL"

DICT_INFO = {
    "nivel_path": "declaracion.situacionPatrimonial.datosEmpleoCargoComision.nivelEmpleoCargoComision",
    "ingreso_path": "declaracion.situacionPatrimonial.ingresos.ingresoMensualNetoDeclarante.valor",
    "obligatorio": False
}

# --- Funciones auxiliares ---

def obtener_valor(doc, path):
    try:
        partes = path.split(".")
        actual = doc
        for p in partes:
            if isinstance(actual, dict):
                actual = actual.get(p, {})
            else:
                return None
        if isinstance(actual, (int, float)):
            return actual
        try:
            return float(actual)
        except Exception:
            return None
    except Exception:
        return None

def obtener_texto(doc, path):
    try:
        partes = path.split(".")
        actual = doc
        for p in partes:
            if isinstance(actual, dict):
                actual = actual.get(p, {})
            else:
                return None
        if isinstance(actual, dict):
            return actual.get("valor") or actual.get("clave") or None
        return str(actual).strip() if actual else None
    except Exception:
        return None

# --- Construcción de referencia (IQR por nivel) ---

def construir_referencia(source):
    niveles = []
    for d in source.find({}, {
        "declaracion.situacionPatrimonial.datosEmpleoCargoComision.nivelEmpleoCargoComision": 1,
        "declaracion.situacionPatrimonial.ingresos.ingresoMensualNetoDeclarante.valor": 1
    }):
        nivel = obtener_texto(d, DICT_INFO["nivel_path"])
        ingreso = obtener_valor(d, DICT_INFO["ingreso_path"])
        if nivel and isinstance(ingreso, (int, float)) and ingreso > 0:
            niveles.append({"nivel": nivel, "ingreso": ingreso})

    df = pd.DataFrame(niveles)
    if df.empty:
        return {}

    referencia = {}
    for nivel, grupo in df.groupby("nivel"):
        if len(grupo) < 5:
            continue
        q1 = grupo["ingreso"].quantile(0.25)
        q3 = grupo["ingreso"].quantile(0.75)
        referencia[nivel] = (q1, q3)
    return referencia

# --- Evaluación de la métrica ---

def evaluar_metrica(doc, referencia):
    nivel = obtener_texto(doc, DICT_INFO["nivel_path"])
    ingreso = obtener_valor(doc, DICT_INFO["ingreso_path"])

    if nivel is None or ingreso is None:
        return "SIN_DATO"

    if nivel not in referencia:
        return "SIN_DATO"

    q1, q3 = referencia[nivel]
    if q1 <= ingreso <= q3:
        return "CUMPLE"
    return "NO_CUMPLE"

# --- Procesamiento MongoDB ---

def procesar_metrica_2_4_01():
    resultados = {"CUMPLE": 0, "NO_CUMPLE": 0, "SIN_DATO": 0}
    operaciones = []
    total = 0
    client = None

    try:
        print(f"Procesando métrica {METRIC_ID}...")
        client = MongoClient(MONGO_URI, serverSelectionTimeoutMS=5000)
        db = client[DB_NAME]
        src = db[SOURCE_COLLECTION_NAME]
        tgt = db[METRICS_COLLECTION_NAME]

        # Construir tabla de referencia IQR por nivel jerárquico
        print("Construyendo referencia de ingresos por nivel jerárquico...")
        referencia = construir_referencia(src)
        print(f"Niveles de referencia generados: {len(referencia)}")

        cursor = src.find({}, {
            "_id": 1,
            "declaracion.situacionPatrimonial.datosEmpleoCargoComision.nivelEmpleoCargoComision": 1,
            "declaracion.situacionPatrimonial.ingresos.ingresoMensualNetoDeclarante.valor": 1
        }, no_cursor_timeout=True)

        for doc in cursor:
            total += 1
            try:
                resultado = evaluar_metrica(doc, referencia)
            except Exception as e:
                resultado = "SIN_DATO"
                print(f"Error en doc {doc.get('_id')}: {e}")

            resultados[resultado] = resultados.get(resultado, 0) + 1
            operaciones.append(UpdateOne({"_id": doc["_id"]}, {"$set": {METRIC_ID: resultado}}, upsert=True))

            if len(operaciones) >= 1000:
                tgt.bulk_write(operaciones)
                operaciones.clear()
                print(f"  > Procesados {total} documentos...")

        if operaciones:
            tgt.bulk_write(operaciones)

        print("\n--- RESUMEN FINAL ---")
        print(f"Total procesados: {total}")
        for k, v in resultados.items():
            print(f"  > {k}: {v}")

    except Exception:
        traceback.print_exc()
    finally:
        if client:
            client.close()
            print("Conexión cerrada.")


if __name__ == "__main__":
    procesar_metrica_2_4_01()
# Out:
# Procesando métrica 2_4_01_DESVIACION_INGRESO_NIVEL...
# Construyendo referencia de ingresos por nivel jerárquico...
# Niveles de referencia generados: 9301
# c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\collection.py:1954: UserWarning: use an explicit session with no_cursor_timeout=True otherwise the cursor may still timeout after 30 minutes, for more info see https://mongodb.com/docs/v4.4/reference/method/cursor.noCursorTimeout/#session-idle-timeout-overrides-nocursortimeout
#   return Cursor(self, *args, **kwargs)
#   > Procesados 1000 documentos...
#   > Procesados 2000 documentos...
#   > Procesados 3000 documentos...
#   > Procesados 4000 documentos...
#   > Procesados 5000 documentos...
#   > Procesados 6000 documentos...
#   > Procesados 7000 documentos...
#   > Procesados 8000 documentos...
#   > Procesados 9000 documentos...
#   > Procesados 10000 documentos...
#   > Procesados 11000 documentos...
#   > Procesados 12000 documentos...
#   > Procesados 13000 documentos...
#   > Procesados 14000 documentos...
#   > Procesados 15000 documentos...
#   > Procesados 16000 documentos...
#   > Procesados 17000 documentos...
#   > Procesados 18000 documentos...
#   > Procesados 19000 documentos...
#   > Procesados 20000 documentos...
#   > Procesados 21000 documentos...
#   > Procesados 22000 documentos...
#   > Procesados 23000 documentos...
#   > Procesados 24000 documentos...
#   > Procesados 25000 documentos...
#   > Procesados 26000 documentos...
#   > Procesados 27000 documentos...
#   > Procesados 28000 documentos...
#   > Procesados 29000 documentos...
#   > Procesados 30000 documentos...
#   > Procesados 31000 documentos...
#   > Procesados 32000 documentos...
#   > Procesados 33000 documentos...
#   > Procesados 34000 documentos...
#   > Procesados 35000 documentos...
#   > Procesados 36000 documentos...
#   > Procesados 37000 documentos...
#   > Procesados 38000 documentos...
#   > Procesados 39000 documentos...
#   > Procesados 40000 documentos...
#   > Procesados 41000 documentos...
# Conexión cerrada.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 152
#     148             print("Conexión cerrada.")
#     151 if __name__ == "__main__":
# --> 152     procesar_metrica_2_4_01()
#
# Cell In[1], line 131, in procesar_metrica_2_4_01()
#     128 operaciones.append(UpdateOne({"_id": doc["_id"]}, {"$set": {METRIC_ID: resultado}}, upsert=True))
#     130 if len(operaciones) >= 1000:
# --> 131     tgt.bulk_write(operaciones)
#     132     operaciones.clear()
#     133     print(f"  > Procesados {total} documentos...")
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\collection.py:791, in Collection.bulk_write(self, requests, ordered, bypass_document_validation, session, comment, let)
#     788         raise TypeError(f"{request!r} is not a valid request") from None
#     790 write_concern = self._write_concern_for(session)
# --> 791 bulk_api_result = blk.execute(write_concern, session, _Op.INSERT)
#     792 if bulk_api_result is not None:
#     793     return BulkWriteResult(bulk_api_result, True)
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\bulk.py:751, in _Bulk.execute(self, write_concern, session, operation)
#     749         return None
#     750 else:
# --> 751     return self.execute_command(generator, write_concern, session, operation)
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\bulk.py:604, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     593     self._execute_command(
#     594         generator,
#     595         write_concern,
#    (...)
#     600         full_result,
#     601     )
#     603 client = self.collection.database.client
# --> 604 _ = client._retryable_write(
#     605     self.is_retryable,
#     606     retryable_bulk,
#     607     session,
#     608     operation,
#     609     bulk=self,  # type: ignore[arg-type]
#     610     operation_id=op_id,
#     611 )
#     613 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     614     _raise_bulk_write_error(full_result)
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2082, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2068 """Execute an operation with consecutive retries if possible
#    2069
#    2070 Returns func()'s return value on success. On error retries the same
#    (...)
#    2079 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2080 """
#    2081 with self._tmp_session(session) as s:
# -> 2082     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1968, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1963 # Ensure that the options supports retry_writes and there is a valid session not in
#    1964 # transaction, otherwise, we will not support retry behavior for this txn.
#    1965 retryable = bool(
#    1966     retryable and self.options.retry_writes and session and not session.in_transaction
#    1967 )
# -> 1968 return self._retry_internal(
#    1969     func=func,
#    1970     session=session,
#    1971     bulk=bulk,
#    1972     operation=operation,
#    1973     retryable=retryable,
#    1974     operation_id=operation_id,
#    1975 )
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)
#    1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)
#    2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2765, in _ClientConnectionRetryable.run(self)
#    2763 self._check_last_error(check_csot=True)
#    2764 try:
# -> 2765     return self._read() if self._is_read else self._write()
#    2766 except ServerSelectionTimeoutError:
#    2767     # The application may think the write was never attempted
#    2768     # if we raise ServerSelectionTimeoutError on the retry
#    2769     # attempt. Raise the original exception instead.
#    2770     self._check_last_error()
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2897, in _ClientConnectionRetryable._write(self)
#    2889         if self._retrying:
#    2890             _debug_log(
#    2891                 _COMMAND_LOGGER,
#    2892                 message=f"Retrying write attempt number {self._attempt_number}",
#    (...)
#    2895                 operationId=self._operation_id,
#    2896             )
# -> 2897         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2898 except PyMongoError as exc:
#    2899     if not self._retryable:
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\bulk.py:593, in _Bulk.execute_command.<locals>.retryable_bulk(session, conn, retryable)
#     590 def retryable_bulk(
#     591     session: Optional[ClientSession], conn: Connection, retryable: bool
#     592 ) -> None:
# --> 593     self._execute_command(
#     594         generator,
#     595         write_concern,
#     596         session,
#     597         conn,
#     598         op_id,
#     599         retryable,
#     600         full_result,
#     601     )
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\bulk.py:538, in _Bulk._execute_command(self, generator, write_concern, session, conn, op_id, retryable, full_result, final_write_concern)
#     536 # Run as many ops as possible in one command.
#     537 if write_concern.acknowledged:
# --> 538     result, to_send = self._execute_batch(bwc, cmd, ops, client)
#     540     # Retryable writeConcernErrors halt the execution of this run.
#     541     wce = result.get("writeConcernError", {})
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\bulk.py:462, in _Bulk._execute_batch(self, bwc, cmd, ops, client)
#     460 else:
#     461     request_id, msg, to_send = bwc.batch_command(cmd, ops)
# --> 462     result = self.write_command(bwc, cmd, request_id, msg, to_send, client)  # type: ignore[arg-type]
#     464 return result, to_send
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\bulk.py:274, in _Bulk.write_command(self, bwc, cmd, request_id, msg, docs, client)
#     272     bwc._start(cmd, request_id, docs)
#     273 try:
# --> 274     reply = bwc.conn.write_command(request_id, msg, bwc.codec)  # type: ignore[misc]
#     275     duration = datetime.datetime.now() - bwc.start_time
#     276     if _COMMAND_LOGGER.isEnabledFor(logging.DEBUG):
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:501, in Connection.write_command(self, request_id, msg, codec_options)
#     493 """Send "insert" etc. command, returning response as a dict.
#     494
#     495 Can raise ConnectionFailure or OperationFailure.
#    (...)
#     498 :param msg: bytes, the command message.
#     499 """
#     500 self.send_message(msg, 0)
# --> 501 reply = self.receive_message(request_id)
#     502 result = reply.command_response(codec_options)
#     504 # Raises NotPrimaryError or OperationFailure.
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:469, in Connection.receive_message(self, request_id)
#     467 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     468 except BaseException as error:
# --> 469     self._raise_connection_failure(error)
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:466, in Connection.receive_message(self, request_id)
#     461 """Receive a raw BSON message or raise ConnectionFailure.
#     462
#     463 If any exception is raised, the socket is closed.
#     464 """
#     465 try:
# --> 466     return receive_message(self, request_id, self.max_message_size)
#     467 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     468 except BaseException as error:
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\network_layer.py:759, in receive_message(conn, request_id, max_message_size)
#     757         deadline = None
#     758 # Ignore the response's request id.
# --> 759 length, _, response_to, op_code = _UNPACK_HEADER(receive_data(conn, 16, deadline))
#     760 # No request_id for exhaust cursor "getMore".
#     761 if request_id is not None:
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\network_layer.py:343, in receive_data(conn, length, deadline)
#     339 try:
#     340     # Use the legacy wait_for_read cancellation approach on PyPy due to PYTHON-5011.
#     341     # also use it on Windows due to PYTHON-5405
#     342     if _PYPY or _WINDOWS:
# --> 343         wait_for_read(conn, deadline)
#     344         if _csot.get_timeout() and deadline is not None:
#     345             conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\network_layer.py:316, in wait_for_read(conn, deadline)
#     314     else:
#     315         timeout = _POLL_TIMEOUT
# --> 316     readable = conn.socket_checker.select(sock, read=True, timeout=timeout)
#     317 if conn.cancel_context.cancelled:
#     318     raise _OperationCancelled("operation cancelled")
#
# File c:\Users\Mauro\anaconda3\Lib\site-packages\pymongo\socket_checker.py:77, in SocketChecker.select(self, sock, read, write, timeout)
#      75 rlist = [sock] if read else []
#      76 wlist = [sock] if write else []
# ---> 77 res = select.select(rlist, wlist, [sock], timeout)
#      78 # select returns a 3-tuple of lists of objects that are
#      79 # ready: subsets of the first three arguments. Return
#      80 # True if any of the lists are not empty.
#      81 return any(res)
#
# KeyboardInterrupt:
