# %% [markdown]
# # Métrica 3_4_01 — Relación entre inmuebles adquiridos por compraventa y nivel jerárquico
#
# | Escenario                                                                       | Condición       | Resultado            |
# | :------------------------------------------------------------------------------ | :-------------- | :------------------- |
# | No hay bienes inmuebles                                                         | —               | ⚪ **SIN_DATO**       |
# | No hay nivel jerárquico declarado                                               | —               | ⚪ **SIN_DATO**       |
# | Número de bienes comprados dentro del rango normal (Q1–Q3 del grupo jerárquico) | —               | 🟢 **CUMPLE (0)**    |
# | Número de bienes comprados fuera del rango esperado                             | `< Q1` o `> Q3` | 🔴 **NO_CUMPLE (1)** |

# %%
import traceback
from pymongo import MongoClient, UpdateOne
from config import MONGO_URI, DB_NAME, SOURCE_COLLECTION_NAME, METRICS_COLLECTION_NAME

METRIC_ID = "3_4_01_RELACION_COMPRAVENTA_NIVEL_JERARQUICO"
BATCH_SIZE = 10000  # 🔧 número de documentos por lote

# Si SESNA define umbrales fijos por nivel, puedes configurarlos aquí
CUARTILES_POR_NIVEL = {
    "OPERATIVO": (0, 2),
    "ENLACE": (0, 3),
    "JEFE_DEPARTAMENTO": (0, 4),
    "DIRECTOR": (0, 5),
    "SUBDIRECTOR": (0, 5),
    "TITULAR": (0, 6),
}

def extraer_lista(doc, path):
    """Extrae una lista desde un path anidado."""
    try:
        partes = path.split(".")
        actuales = [doc]
        for p in partes:
            siguientes = []
            for actual in actuales:
                if isinstance(actual, dict):
                    valor = actual.get(p)
                    if valor is None:
                        continue
                    if isinstance(valor, list):
                        siguientes.extend(valor)
                    else:
                        siguientes.append(valor)
                elif isinstance(actual, list):
                    for sub in actual:
                        if isinstance(sub, dict):
                            valor = sub.get(p)
                            if valor is None:
                                continue
                            if isinstance(valor, list):
                                siguientes.extend(valor)
                            else:
                                siguientes.append(valor)
            actuales = siguientes
        return [a for a in actuales if isinstance(a, dict)]
    except:
        return []


def extraer_valor(doc, path):
    """Extrae un valor único (nivel jerárquico)."""
    try:
        partes = path.split(".")
        actual = doc
        for p in partes:
            if isinstance(actual, dict):
                actual = actual.get(p)
            elif isinstance(actual, list) and len(actual) > 0:
                actual = actual[0].get(p)
            else:
                return None
        return actual
    except:
        return None


def evaluar_metrica(doc):
    bienes = extraer_lista(doc, "declaracion.situacionPatrimonial.bienesInmuebles.bienInmueble")
    nivel = str(extraer_valor(doc, "declaracion.situacionPatrimonial.datosEmpleoCargoComision.nivel") or "").upper()

    if not bienes:
        return "SIN_DATO"
    if not nivel:
        return "SIN_DATO"

    n_compraventa = sum(
        1 for b in bienes if str(b.get("formaAdquisicion", "")).upper() in ["COMPRA", "COMPRA-VENTA", "COMPRAVENTA"]
    )

    if nivel not in CUARTILES_POR_NIVEL:
        return "SIN_DATO"

    q1, q3 = CUARTILES_POR_NIVEL[nivel]
    if n_compraventa < q1 or n_compraventa > q3:
        return "NO_CUMPLE"
    return "CUMPLE"


def procesar_metrica():
    client = MongoClient(MONGO_URI, serverSelectionTimeoutMS=5000)
    db = client[DB_NAME]
    src = db[SOURCE_COLLECTION_NAME]
    tgt = db[METRICS_COLLECTION_NAME]

    total_docs = src.estimated_document_count()
    print(f"🚀 Procesando {METRIC_ID} con {total_docs:,} documentos...\n")

    skip = 0
    procesados = 0
    lote = 0

    try:
        while True:
            cursor = list(src.find({}, {
                "_id": 1,
                "declaracion.situacionPatrimonial.bienesInmuebles.bienInmueble": 1,
                "declaracion.situacionPatrimonial.datosEmpleoCargoComision.nivel": 1
            }).skip(skip).limit(BATCH_SIZE))

            if not cursor:
                break

            operaciones = []
            for doc in cursor:
                try:
                    resultado = evaluar_metrica(doc)
                except Exception as e:
                    resultado = "SIN_DATO"
                    print(f"[Error doc {doc.get('_id')}] {e}")

                operaciones.append(UpdateOne(
                    {"_id": doc["_id"]},
                    {"$set": {METRIC_ID: resultado}},
                    upsert=True
                ))

            if operaciones:
                tgt.bulk_write(operaciones)
                procesados += len(operaciones)
                lote += 1
                print(f"  🔄 Lote {lote:,} → {procesados:,}/{total_docs:,} procesados", flush=True)

            skip += BATCH_SIZE

        print("\n✅ Procesamiento completado.")
        print(f"Total final: {procesados:,}/{total_docs:,} documentos actualizados.")

    except Exception:
        traceback.print_exc()
    finally:
        client.close()
        print("🔒 Conexión cerrada.")


if __name__ == "__main__":
    procesar_metrica()
# Out:
# 🚀 Procesando 3_4_01_RELACION_COMPRAVENTA_NIVEL_JERARQUICO con 8,942,592 documentos...
#
#   🔄 Lote 1 → 10,000/8,942,592 procesados
#   🔄 Lote 2 → 20,000/8,942,592 procesados
#   🔄 Lote 3 → 30,000/8,942,592 procesados
#   🔄 Lote 4 → 40,000/8,942,592 procesados
#   🔄 Lote 5 → 50,000/8,942,592 procesados
#   🔄 Lote 6 → 60,000/8,942,592 procesados
#   🔄 Lote 7 → 70,000/8,942,592 procesados
#   🔄 Lote 8 → 80,000/8,942,592 procesados
#   🔄 Lote 9 → 90,000/8,942,592 procesados
#   🔄 Lote 10 → 100,000/8,942,592 procesados
#   🔄 Lote 11 → 110,000/8,942,592 procesados
#   🔄 Lote 12 → 120,000/8,942,592 procesados
#   🔄 Lote 13 → 130,000/8,942,592 procesados
#   🔄 Lote 14 → 140,000/8,942,592 procesados
#   🔄 Lote 15 → 150,000/8,942,592 procesados
#   🔄 Lote 16 → 160,000/8,942,592 procesados
#   🔄 Lote 17 → 170,000/8,942,592 procesados
#   🔄 Lote 18 → 180,000/8,942,592 procesados
#   🔄 Lote 19 → 190,000/8,942,592 procesados
#   🔄 Lote 20 → 200,000/8,942,592 procesados
#   🔄 Lote 21 → 210,000/8,942,592 procesados
#   🔄 Lote 22 → 220,000/8,942,592 procesados
#   🔄 Lote 23 → 230,000/8,942,592 procesados
#   🔄 Lote 24 → 240,000/8,942,592 procesados
#   🔄 Lote 25 → 250,000/8,942,592 procesados
#   🔄 Lote 26 → 260,000/8,942,592 procesados
#   🔄 Lote 27 → 270,000/8,942,592 procesados
#   🔄 Lote 28 → 280,000/8,942,592 procesados
#   🔄 Lote 29 → 290,000/8,942,592 procesados
#   🔄 Lote 30 → 300,000/8,942,592 procesados
#   🔄 Lote 31 → 310,000/8,942,592 procesados
#   🔄 Lote 32 → 320,000/8,942,592 procesados
#   🔄 Lote 33 → 330,000/8,942,592 procesados
#   🔄 Lote 34 → 340,000/8,942,592 procesados
#   🔄 Lote 35 → 350,000/8,942,592 procesados
#   🔄 Lote 36 → 360,000/8,942,592 procesados
#   🔄 Lote 37 → 370,000/8,942,592 procesados
#   🔄 Lote 38 → 380,000/8,942,592 procesados
#   🔄 Lote 39 → 390,000/8,942,592 procesados
#   🔄 Lote 40 → 400,000/8,942,592 procesados
#   🔄 Lote 41 → 410,000/8,942,592 procesados
#   🔄 Lote 42 → 420,000/8,942,592 procesados
#   🔄 Lote 43 → 430,000/8,942,592 procesados
#   🔄 Lote 44 → 440,000/8,942,592 procesados
#   🔄 Lote 45 → 450,000/8,942,592 procesados
#   🔄 Lote 46 → 460,000/8,942,592 procesados
#   🔄 Lote 47 → 470,000/8,942,592 procesados
#   🔄 Lote 48 → 480,000/8,942,592 procesados
#   🔄 Lote 49 → 490,000/8,942,592 procesados
#   🔄 Lote 50 → 500,000/8,942,592 procesados
