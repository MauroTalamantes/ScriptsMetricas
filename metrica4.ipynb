# %% [markdown]
# # Métrica 1.1.04: "Congruencia del RFC a partir del nombre"

# %%
import re
import urllib.parse
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure, OperationFailure
import unicodedata # Para normalizar y quitar acentos
from config import MONGO_URI, DB_NAME, SOURCE_COLLECTION_NAME, METRICS_COLLECTION_NAME

# --- 1. CONFIGURACIÓN BÁSICA ---
METRIC_ID = "1_1_04_RFC_VS_NOMBRE"

# --- 2. LÓGICA PURA DE LA MÉTRICA ---

# --- Funciones de Normalización (Reutilizadas de Métrica 1.1.03) ---

def normalize_for_curp(name: str) -> str:
    """
    Limpia y normaliza un nombre/apellido para las reglas de RFC/CURP.
    - Quita acentos (ej. JOSÉ -> JOSE)
    - Convierte a mayúsculas
    - Maneja 'Ñ' -> 'X'
    - Quita prefijos y artículos comunes (DE, LA, DEL, Y, ETC.)
    - Toma el primer nombre/apellido en caso de compuestos.
    """
    if not isinstance(name, str):
        return ""
        
    s = ''.join(c for c in unicodedata.normalize('NFD', name)
                if unicodedata.category(c) != 'Mn')
    s = s.upper().strip()
    s = s.replace('Ñ', 'X')
    
    prefixes_to_remove = [
        'DE ', 'DEL ', 'LA ', 'LOS ', 'LAS ', 'Y ', 'MC ', 'MAC ', 'VON ', 'VAN '
    ]
    
    for prefix in prefixes_to_remove:
        if s.startswith(prefix):
            s = s[len(prefix):]
            
    s = s.split(' ')[0]
    s = re.sub(r'[^A-Z]', '', s)
    return s

def get_internal_vowel(s: str) -> str:
    """Obtiene la primera vocal INTERNA (después del primer caracter)."""
    if len(s) <= 1:
        return 'X'
    vowels = re.sub(r'[^AEIOU]', '', s[1:])
    return vowels[0] if vowels else 'X'

# --- Lógica Específica de la Métrica 1.1.04 ---

def validar_rfc_vs_nombre(rfc_base: str, nombre: str, ap_paterno: str, ap_materno: str) -> str:
    """
    Valida la congruencia del RFC (primeros 4 caracteres) vs los datos del nombre
    según las reglas estándar del SAT.
    """
    
    # --- Validación de Entradas ---
    # Necesitamos RFC (base de 10), nombre y primer apellido.
    if not all([rfc_base, nombre, ap_paterno]):
        return "SIN_DATO"
        
    if len(rfc_base) != 10:
        # La base del RFC (sin homoclave) debe tener 10 caracteres
        return "NO_CUMPLE" 
        
    # --- Normalización de Nombres ---
    n_nombre = normalize_for_curp(nombre)
    n_paterno = normalize_for_curp(ap_paterno)
    n_materno = normalize_for_curp(ap_materno)
    
    if not all([n_nombre, n_paterno]):
        return "SIN_DATO"
        
    # --- Extracción de caracteres de la persona ---
    try:
        # Regla 1: Primera letra del primer apellido.
        c_1_calc = n_paterno[0]
        
        # Regla 2: Primera vocal interna del primer apellido.
        # (Si la primera letra es vocal, se toma la segunda vocal.
        #  Esta lógica de "get_internal_vowel" es más simple y 
        #  cubre el 99% de los casos. La regla real del SAT es más compleja).
        # Para la métrica 1.1.04, la regla dice "Si c_1 fue consonante, entonces 
        # c_2 debe ser la primera vocal... Si c_1 fue vocal, entonces c_2 
        # debe ser la segunda vocal".
        
        vowels_paterno = re.sub(r'[^AEIOU]', '', n_paterno)
        c_2_calc = 'X'
        if c_1_calc in 'AEIOU':
             c_2_calc = vowels_paterno[1] if len(vowels_paterno) > 1 else 'X'
        else:
             c_2_calc = vowels_paterno[0] if vowels_paterno else 'X'

        # Regla 3: Primera letra del segundo apellido.
        c_3_calc = n_materno[0] if n_materno else 'X' # 'X' si no hay apellido materno
        
        # Regla 4: Primera letra del primer nombre.
        c_4_calc = n_nombre[0]
        
    except IndexError:
        return "NO_CUMPLE" # Datos de nombre inválidos (ej. "A")
        
    # --- Extracción de caracteres del RFC ---
    c_1_rfc = rfc_base[0]
    c_2_rfc = rfc_base[1]
    c_3_rfc = rfc_base[2]
    c_4_rfc = rfc_base[3]
    
    # --- Comparación Final ---
    if (c_1_calc == c_1_rfc and
        c_2_calc == c_2_rfc and
        c_3_calc == c_3_rfc and
        c_4_calc == c_4_rfc):
        return "CUMPLE"
    else:
        # Imprimimos los valores calculados vs los reales para depuración
        print(f"    > DEBUG: Calculado [{c_1_calc}{c_2_calc}{c_3_calc}{c_4_calc}] vs RFC [{c_1_rfc}{c_2_rfc}{c_3_rfc}{c_4_rfc}]")
        return "NO_CUMPLE"

# --- 3. EL FLUJO DEL WORKER (PROCESAMIENTO POR LOTES) ---
def procesar_todas_las_declaraciones_rfc_nombre():
    """
    Procesa TODAS las declaraciones de la colección de origen
    y guarda los resultados de la Métrica 1.1.04 en la colección 'metricas'.
    """
    client = None
    
    # Contadores
    total_documentos = 0
    cumple = 0
    no_cumple = 0
    sin_dato = 0
    
    try:
        # --- A. CONECTAR A LA BASE DE DATOS ---
        print(f"Conectando a MongoDB en {DB_NAME}...")
        client = MongoClient(MONGO_URI, serverSelectionTimeoutMS=5000)
        client.admin.command('ping') 
        db = client[DB_NAME]
        
        source_collection = db[SOURCE_COLLECTION_NAME]
        target_collection = db[METRICS_COLLECTION_NAME]
        
        print("¡Conexión exitosa!")
        print(f"Leyendo de: {SOURCE_COLLECTION_NAME}")
        print(f"Escribiendo en: {METRICS_COLLECTION_NAME}")
        print("--- INICIANDO PROCESAMIENTO POR LOTES (Métrica 1.1.04 - RFC vs Nombre) ---")

        # --- B. BUSCAR TODOS LOS DOCUMENTOS ---
        # Proyección optimizada
        proyeccion = {
            "_id": 1,
            "declaracion.situacionPatrimonial.datosGenerales.rfc.rfc": 1, # Base del RFC
            "declaracion.situacionPatrimonial.datosGenerales.nombre": 1,
            "declaracion.situacionPatrimonial.datosGenerales.primerApellido": 1,
            "declaracion.situacionPatrimonial.datosGenerales.segundoApellido": 1,
        }
        
        for doc in source_collection.find({}, proyeccion):
            total_documentos += 1
            original_id = doc["_id"]

            # --- C. LEER DATOS Y EJECUTAR MÉTRICA ---
            rfc_base = None
            nombre = None
            ap_paterno = None
            ap_materno = None
            
            try:
                # Navegación segura
                datos_generales = doc.get("declaracion", {}).get("situacionPatrimonial", {}).get("datosGenerales", {})
                if datos_generales:
                    rfc_object = datos_generales.get("rfc")
                    if isinstance(rfc_object, dict):
                        rfc_base = rfc_object.get("rfc")
                    
                    nombre = datos_generales.get("nombre")
                    ap_paterno = datos_generales.get("primerApellido")
                    ap_materno = datos_generales.get("segundoApellido")
            except AttributeError:
                pass # Se queda todo en None

            # Ejecutamos la lógica de la métrica
            resultado_metrica = validar_rfc_vs_nombre(rfc_base, nombre, ap_paterno, ap_materno)
            
            # Actualizamos contadores
            if resultado_metrica == "CUMPLE":
                cumple += 1
            elif resultado_metrica == "NO_CUMPLE":
                no_cumple += 1
            else:
                sin_dato += 1

            # --- CONSERVAMOS TU SALIDA DE CONSOLA ---
            print(f"\nProcesando Documento ID: {original_id}")
            print("--- RESULTADO DEL ANÁLISIS ---")
            print(f"  > RFC Base: '{rfc_base}'")
            print(f"  > Nombre: '{nombre}', Paterno: '{ap_paterno}', Materno: '{ap_materno}'")
            print(f"  > Resultado de la Métrica: {resultado_metrica}")
            print("---------------------------------")
            # --- FIN DE LA SALIDA DE CONSOLA ---

            # --- D. GUARDAR RESULTADO EN LA COLECCIÓN 'metricas' ---
            filtro = { "_id": original_id }
            actualizacion = {
                "$set": {
                    METRIC_ID: resultado_metrica
                }
            }
            target_collection.update_one(filtro, actualizacion, upsert=True)

            print(f"¡Resultado guardado/actualizado en 'metricas' para el ID: {original_id}!")

        print("\n--- PROCESAMIENTO POR LOTES FINALIZADO ---")
        print("Resumen (Métrica 1.1.04 - RFC vs Nombre):")
        print(f"  > Documentos Totales Procesados: {total_documentos}")
        print(f"  > Métrica 'CUMPLE': {cumple}")
        print(f"  > Métrica 'NO_CUMPLE': {no_cumple}")
        print(f"  > Métrica 'SIN_DATO': {sin_dato}")

    except ConnectionFailure:
        print("Error: No se pudo conectar a la base de datos.")
    except OperationFailure as e:
        print(f"Error en la operación de la base de datos: {e.details}")
    except Exception as e:
        print(f"Ocurrió un error inesperado: {e}")
    finally:
        if client:
            client.close()
            print("Conexión cerrada.")

# --- 4. EJECUTAR EL SCRIPT ---
if __name__ == "__main__":
    procesar_todas_las_declaraciones_rfc_nombre()
# Out:
# Conectando a MongoDB en sistema1...
# ¡Conexión exitosa!
# Leyendo de: all_data_20251021
# Escribiendo en: metricas
# --- INICIANDO PROCESAMIENTO POR LOTES (Métrica 1.1.04 - RFC vs Nombre) ---
#
# Procesando Documento ID: 68f81b8800535f910a29f694
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'GUEL', Materno: 'MONTOYA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f694!
#
# Procesando Documento ID: 68f81b8800535f910a29f695
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: '01FGR0026U NORMA ELIZABETH', Paterno: 'MAURICIO', Materno: 'MAURICIO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f695!
#
# Procesando Documento ID: 68f81b8800535f910a29f696
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'DIAZ', Materno: 'CALDERON'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f696!
#
# Procesando Documento ID: 68f81b8800535f910a29f697
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'A', Paterno: 'HERNANDEZ', Materno: 'MOR'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f697!
#
# Procesando Documento ID: 68f81b8800535f910a29f698
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'GAMBOA', Materno: 'CASTRO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f698!
#
# Procesando Documento ID: 68f81b8800535f910a29f699
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'REYES', Materno: 'DIAZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f699!
#
# Procesando Documento ID: 68f81b8800535f910a29f69a
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'REYES', Materno: 'GUZMAN'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f69a!
#
# Procesando Documento ID: 68f81b8800535f910a29f69b
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'PADILLA', Materno: 'BADILLO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f69b!
#
# Procesando Documento ID: 68f81b8800535f910a29f69c
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'GAMBOA', Materno: 'CASTRO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f69c!
#
# Procesando Documento ID: 68f81b8800535f910a29f69d
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'DURAN', Materno: 'ESPARZA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f69d!
#
# Procesando Documento ID: 68f81b8800535f910a29f69e
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'SANDOVAL', Materno: 'RANGEL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f69e!
#
# Procesando Documento ID: 68f81b8800535f910a29f69f
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'GAMBOA', Materno: 'CASTRO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f69f!
#
# Procesando Documento ID: 68f81b8800535f910a29f6a0
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'GUILLEN', Materno: 'VILLALOBOS'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6a0!
#
# Procesando Documento ID: 68f81b8800535f910a29f6a1
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'HERRERA', Materno: 'VALENZUELA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6a1!
#
# Procesando Documento ID: 68f81b8800535f910a29f6a2
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'MORENO', Materno: 'DELGADO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6a2!
#
# Procesando Documento ID: 68f81b8800535f910a29f6a3
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'VALADEZ', Materno: 'RANGEL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6a3!
#
# Procesando Documento ID: 68f81b8800535f910a29f6a4
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'MARTINEZ', Materno: 'QUEZADA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6a4!
#
# Procesando Documento ID: 68f81b8800535f910a29f6a5
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'DURAN', Materno: 'ESPARZA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6a5!
#
# Procesando Documento ID: 68f81b8800535f910a29f6a6
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'QUEZADA', Materno: 'CASTAÑON'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6a6!
#
# Procesando Documento ID: 68f81b8800535f910a29f6a7
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'GUILLEN', Materno: 'VILLALOBOS'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6a7!
#
# Procesando Documento ID: 68f81b8800535f910a29f6a8
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'JAIMEZ', Materno: 'HERNANDEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6a8!
#
# Procesando Documento ID: 68f81b8800535f910a29f6a9
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'SERRANO', Materno: 'BONILLA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6a9!
#
# Procesando Documento ID: 68f81b8800535f910a29f6aa
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'MARTINEZ', Materno: 'TISCAREÑO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6aa!
#
# Procesando Documento ID: 68f81b8800535f910a29f6ab
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'MARTINEZ', Materno: 'QUEZADA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6ab!
#
# Procesando Documento ID: 68f81b8800535f910a29f6ac
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'GUILLEN', Materno: 'VILLALOBOS'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6ac!
#
# Procesando Documento ID: 68f81b8800535f910a29f6ad
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'BACA', Materno: 'MORALES'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6ad!
#
# Procesando Documento ID: 68f81b8800535f910a29f6ae
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'SERRANO', Materno: 'BONILLA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6ae!
#
# Procesando Documento ID: 68f81b8800535f910a29f6af
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'DIAZ', Materno: 'CALDERON'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6af!
#
# Procesando Documento ID: 68f81b8800535f910a29f6b0
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'SOTO', Materno: 'MACARIO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6b0!
#
# Procesando Documento ID: 68f81b8800535f910a29f6b1
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'JAIMEZ', Materno: 'HERNANDEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6b1!
#
# Procesando Documento ID: 68f81b8800535f910a29f6b2
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'BERNAL', Materno: 'BOCANEGRA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6b2!
#
# Procesando Documento ID: 68f81b8800535f910a29f6b3
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'BACA', Materno: 'MORALES'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6b3!
#
# Procesando Documento ID: 68f81b8800535f910a29f6b4
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'RODRIGUEZ', Materno: 'CARDONA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6b4!
#
# Procesando Documento ID: 68f81b8800535f910a29f6b5
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'BACA', Materno: 'MORALES'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6b5!
#
# Procesando Documento ID: 68f81b8800535f910a29f6b6
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'BONILLA', Materno: 'GONZALEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6b6!
#
# Procesando Documento ID: 68f81b8800535f910a29f6b7
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'X', Materno: 'TORRES'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6b7!
#
# Procesando Documento ID: 68f81b8800535f910a29f6b8
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'BERNAL', Materno: 'BOCANEGRA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6b8!
#
# Procesando Documento ID: 68f81b8800535f910a29f6b9
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'RUVALCABA', Materno: 'LOPEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6b9!
#
# Procesando Documento ID: 68f81b8800535f910a29f6ba
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'VALADEZ', Materno: 'RANGEL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6ba!
#
# Procesando Documento ID: 68f81b8800535f910a29f6bb
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'BERNAL', Materno: 'BOCANEGRA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6bb!
#
# Procesando Documento ID: 68f81b8800535f910a29f6bc
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'MARTINEZ', Materno: 'LAGUNES'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6bc!
#
# Procesando Documento ID: 68f81b8800535f910a29f6bd
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'DIAZ', Materno: 'CALDERON'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6bd!
#
# Procesando Documento ID: 68f81b8800535f910a29f6be
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'RODRIGUEZ', Materno: 'CARDONA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6be!
#
# Procesando Documento ID: 68f81b8800535f910a29f6bf
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'MORENO', Materno: 'DELGADO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6bf!
#
# Procesando Documento ID: 68f81b8800535f910a29f6c0
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'GAMBOA', Materno: 'CASTRO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6c0!
#
# Procesando Documento ID: 68f81b8800535f910a29f6c1
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'PADILLA', Materno: 'BADILLO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6c1!
#
# Procesando Documento ID: 68f81b8800535f910a29f6c2
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'SANDOVAL', Materno: 'RANGEL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6c2!
#
# Procesando Documento ID: 68f81b8800535f910a29f6c3
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'REYES', Materno: 'DIAZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6c3!
#
# Procesando Documento ID: 68f81b8800535f910a29f6c4
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'MONROY', Materno: 'PIZA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6c4!
#
# Procesando Documento ID: 68f81b8800535f910a29f6c5
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'BACA', Materno: 'MORALES'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6c5!
#
# Procesando Documento ID: 68f81b8800535f910a29f6c6
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'CASILLAS', Materno: 'CASILLAS SOLEDAD'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6c6!
#
# Procesando Documento ID: 68f81b8800535f910a29f6c7
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'MORENO', Materno: 'DELGADO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6c7!
#
# Procesando Documento ID: 68f81b8800535f910a29f6c8
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'RUIZ', Materno: 'IBARRA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6c8!
#
# Procesando Documento ID: 68f81b8800535f910a29f6c9
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'SERRANO', Materno: 'BONILLA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6c9!
#
# Procesando Documento ID: 68f81b8800535f910a29f6ca
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'BONILLA', Materno: 'GONZALEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6ca!
#
# Procesando Documento ID: 68f81b8800535f910a29f6cb
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'RODRIGUEZ', Materno: 'CARDONA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6cb!
#
# Procesando Documento ID: 68f81b8800535f910a29f6cc
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'RUVALCABA', Materno: 'LOPEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6cc!
#
# Procesando Documento ID: 68f81b8800535f910a29f6cd
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'PADILLA', Materno: 'BADILLO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6cd!
#
# Procesando Documento ID: 68f81b8800535f910a29f6ce
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'BACA', Materno: 'MORALES'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6ce!
#
# Procesando Documento ID: 68f81b8800535f910a29f6cf
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'SERRANO', Materno: 'BONILLA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6cf!
#
# Procesando Documento ID: 68f81b8800535f910a29f6d0
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'RODRIGUEZ', Materno: 'CARDONA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6d0!
#
# Procesando Documento ID: 68f81b8800535f910a29f6d1
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'GUEL', Materno: 'MONTOYA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6d1!
#
# Procesando Documento ID: 68f81b8800535f910a29f6d2
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'VALADEZ', Materno: 'RANGEL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6d2!
#
# Procesando Documento ID: 68f81b8800535f910a29f6d3
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'TORRES', Materno: ''
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6d3!
#
# Procesando Documento ID: 68f81b8800535f910a29f6d4
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'REYES', Materno: 'DIAZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6d4!
#
# Procesando Documento ID: 68f81b8800535f910a29f6d5
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'JAIMEZ', Materno: 'HERNANDEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6d5!
#
# Procesando Documento ID: 68f81b8800535f910a29f6d6
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'DURAN', Materno: 'ESPARZA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6d6!
#
# Procesando Documento ID: 68f81b8800535f910a29f6d7
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'MARTINEZ', Materno: 'QUEZADA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6d7!
#
# Procesando Documento ID: 68f81b8800535f910a29f6d8
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'RODRIGUEZ', Materno: 'CARDONA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6d8!
#
# Procesando Documento ID: 68f81b8800535f910a29f6d9
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'VALADEZ', Materno: 'RANGEL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6d9!
#
# Procesando Documento ID: 68f81b8800535f910a29f6da
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'JAIMEZ', Materno: 'HERNANDEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6da!
#
# Procesando Documento ID: 68f81b8800535f910a29f6db
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'REYES', Materno: 'DIAZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6db!
#
# Procesando Documento ID: 68f81b8800535f910a29f6dc
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'SANDOVAL', Materno: 'RANGEL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6dc!
#
# Procesando Documento ID: 68f81b8800535f910a29f6dd
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'JAIMEZ', Materno: 'HERNANDEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6dd!
#
# Procesando Documento ID: 68f81b8800535f910a29f6de
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'REYES', Materno: 'GUZMAN'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6de!
#
# Procesando Documento ID: 68f81b8800535f910a29f6df
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'SERRANO', Materno: 'BONILLA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6df!
#
# Procesando Documento ID: 68f81b8800535f910a29f6e0
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'SANDOVAL', Materno: 'RANGEL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6e0!
#
# Procesando Documento ID: 68f81b8800535f910a29f6e1
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'X', Materno: 'TORRES'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6e1!
#
# Procesando Documento ID: 68f81b8800535f910a29f6e2
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'SERRANO', Materno: 'BONILLA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6e2!
#
# Procesando Documento ID: 68f81b8800535f910a29f6e3
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'MONROY', Materno: 'PIZA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6e3!
#
# Procesando Documento ID: 68f81b8800535f910a29f6e4
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'SOTO', Materno: 'MACARIO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6e4!
#
# Procesando Documento ID: 68f81b8800535f910a29f6e5
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'RUIZ', Materno: 'IBARRA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6e5!
#
# Procesando Documento ID: 68f81b8800535f910a29f6e6
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ABEL', Paterno: 'ALVAREZ', Materno: 'DIAZ DE LEON'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6e6!
#
# Procesando Documento ID: 68f81b8800535f910a29f6e7
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'REYES', Materno: 'GUZMAN'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6e7!
#
# Procesando Documento ID: 68f81b8800535f910a29f6e8
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'QUEZADA', Materno: 'CASTAÑON'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6e8!
#
# Procesando Documento ID: 68f81b8800535f910a29f6e9
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ABEL', Paterno: 'ALVAREZ', Materno: 'DIAZ DE LEON'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6e9!
#
# Procesando Documento ID: 68f81b8800535f910a29f6ea
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ABEL', Paterno: 'ALVAREZ', Materno: 'DIAZ DE LEON'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6ea!
#
# Procesando Documento ID: 68f81b8800535f910a29f6eb
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'HERRERA', Materno: 'VALENZUELA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6eb!
#
# Procesando Documento ID: 68f81b8800535f910a29f6ec
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ADALBERTO', Paterno: 'PADILLA', Materno: 'MURIEL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6ec!
#
# Procesando Documento ID: 68f81b8800535f910a29f6ed
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ADALBERTO', Paterno: 'PADILLA', Materno: 'MURIEL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6ed!
#
# Procesando Documento ID: 68f81b8800535f910a29f6ee
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'DIAZ', Materno: 'CALDERON'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6ee!
#
# Procesando Documento ID: 68f81b8800535f910a29f6ef
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALBERTO', Paterno: 'RUIZ ESPARZA', Materno: 'GUTIERREZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6ef!
#
# Procesando Documento ID: 68f81b8800535f910a29f6f0
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ADALBERTO', Paterno: 'PADILLA', Materno: 'MURIEL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6f0!
#
# Procesando Documento ID: 68f81b8800535f910a29f6f1
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON', Paterno: 'SOTO', Materno: 'MACARIO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6f1!
#
# Procesando Documento ID: 68f81b8800535f910a29f6f2
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON AGUSTIN', Paterno: 'LOPEZ', Materno: 'LOPEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6f2!
#
# Procesando Documento ID: 68f81b8800535f910a29f6f3
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALBERTO', Paterno: 'RUIZ ESPARZA', Materno: 'GUTIERREZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6f3!
#
# Procesando Documento ID: 68f81b8800535f910a29f6f4
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALDAHIR', Paterno: 'DOMINGUEZ', Materno: 'ENRIQUEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6f4!
#
# Procesando Documento ID: 68f81b8800535f910a29f6f5
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON AGUSTIN', Paterno: 'LOPEZ', Materno: 'LOPEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6f5!
#
# Procesando Documento ID: 68f81b8800535f910a29f6f6
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON AGUSTIN', Paterno: 'LOPEZ', Materno: 'LOPEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6f6!
#
# Procesando Documento ID: 68f81b8800535f910a29f6f7
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALEJANDRO', Paterno: 'SOLANO', Materno: 'RODARTE'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6f7!
#
# Procesando Documento ID: 68f81b8800535f910a29f6f8
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALBERTO', Paterno: 'RUIZ ESPARZA', Materno: 'GUTIERREZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6f8!
#
# Procesando Documento ID: 68f81b8800535f910a29f6f9
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALDAHIR', Paterno: 'DOMINGUEZ', Materno: 'ENRIQUEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6f9!
#
# Procesando Documento ID: 68f81b8800535f910a29f6fa
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALDAHIR', Paterno: 'DOMINGUEZ', Materno: 'ENRIQUEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6fa!
#
# Procesando Documento ID: 68f81b8800535f910a29f6fb
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALDAHIR', Paterno: 'DOMINGUEZ', Materno: 'ENRIQUEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6fb!
#
# Procesando Documento ID: 68f81b8800535f910a29f6fc
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALEJANDRO', Paterno: 'AGUIRRE', Materno: 'ROMO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6fc!
#
# Procesando Documento ID: 68f81b8800535f910a29f6fd
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALDAHIR', Paterno: 'DOMINGUEZ', Materno: 'ENRIQUEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6fd!
#
# Procesando Documento ID: 68f81b8800535f910a29f6fe
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALEJANDRO', Paterno: 'AGUIRRE', Materno: 'ROMO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6fe!
#
# Procesando Documento ID: 68f81b8800535f910a29f6ff
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALEJANDRO', Paterno: 'SOLANO', Materno: 'RODARTE'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f6ff!
#
# Procesando Documento ID: 68f81b8800535f910a29f700
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALEJANDRO', Paterno: 'AGUIRRE', Materno: 'ROMO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f700!
#
# Procesando Documento ID: 68f81b8800535f910a29f701
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALEJANDRO', Paterno: 'SOLANO', Materno: 'RODARTE'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f701!
#
# Procesando Documento ID: 68f81b8800535f910a29f702
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALEJANDRO', Paterno: 'PLASCENCIA', Materno: 'HERNANDEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f702!
#
# Procesando Documento ID: 68f81b8800535f910a29f703
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALEJANDRO', Paterno: 'AGUIRRE', Materno: 'ROMO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f703!
#
# Procesando Documento ID: 68f81b8800535f910a29f704
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALEJANDRO', Paterno: 'PLASCENCIA', Materno: 'HERNANDEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f704!
#
# Procesando Documento ID: 68f81b8800535f910a29f705
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALEJANDRO', Paterno: 'AGUIRRE', Materno: 'ROMO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f705!
#
# Procesando Documento ID: 68f81b8800535f910a29f706
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALEJANDRO', Paterno: 'SOLANO', Materno: 'RODARTE'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f706!
#
# Procesando Documento ID: 68f81b8800535f910a29f707
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALEJANDRO', Paterno: 'PLASCENCIA', Materno: 'HERNANDEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f707!
#
# Procesando Documento ID: 68f81b8800535f910a29f708
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALEJANDRO', Paterno: 'PLASCENCIA', Materno: 'HERNANDEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f708!
#
# Procesando Documento ID: 68f81b8800535f910a29f709
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALFREDO', Paterno: 'RAMIREZ', Materno: 'BARAJAS'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f709!
#
# Procesando Documento ID: 68f81b8800535f910a29f70a
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALFONSO', Paterno: 'MARTINEZ', Materno: 'MARTINEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f70a!
#
# Procesando Documento ID: 68f81b8800535f910a29f70b
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALFREDO', Paterno: 'RAMIREZ', Materno: 'BARAJAS'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f70b!
#
# Procesando Documento ID: 68f81b8800535f910a29f70c
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALFONSO', Paterno: 'MARTINEZ', Materno: 'MARTINEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f70c!
#
# Procesando Documento ID: 68f81b8800535f910a29f70d
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALFONSO', Paterno: 'MARTINEZ', Materno: 'MARTINEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f70d!
#
# Procesando Documento ID: 68f81b8800535f910a29f70e
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALFREDO', Paterno: 'RODRIGUEZ', Materno: 'SILVA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f70e!
#
# Procesando Documento ID: 68f81b8800535f910a29f70f
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALFREDO', Paterno: 'RODRIGUEZ', Materno: 'SILVA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f70f!
#
# Procesando Documento ID: 68f81b8800535f910a29f710
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALFREDO', Paterno: 'RODRIGUEZ', Materno: 'SILVA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f710!
#
# Procesando Documento ID: 68f81b8800535f910a29f711
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALFREDO', Paterno: 'RODRIGUEZ', Materno: 'SILVA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f711!
#
# Procesando Documento ID: 68f81b8800535f910a29f712
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALFREDO', Paterno: 'RODRIGUEZ', Materno: 'SILVA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f712!
#
# Procesando Documento ID: 68f81b8800535f910a29f713
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ANTONIO', Paterno: 'TREJO', Materno: 'ZUÑIGA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f713!
#
# Procesando Documento ID: 68f81b8800535f910a29f714
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALFREDO', Paterno: 'RODRIGUEZ', Materno: 'SILVA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f714!
#
# Procesando Documento ID: 68f81b8800535f910a29f715
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALFREDO', Paterno: 'RODRIGUEZ', Materno: 'SILVA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f715!
#
# Procesando Documento ID: 68f81b8800535f910a29f716
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALFREDO', Paterno: 'RAMIREZ', Materno: 'BARAJAS'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f716!
#
# Procesando Documento ID: 68f81b8800535f910a29f717
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ANTONIO', Paterno: 'TREJO', Materno: 'ZUÑIGA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f717!
#
# Procesando Documento ID: 68f81b8800535f910a29f718
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON AQUILES', Paterno: 'SANCHEZ', Materno: 'GUERRA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f718!
#
# Procesando Documento ID: 68f81b8800535f910a29f719
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ANTONIO', Paterno: 'ROBLEDO', Materno: 'REYES'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f719!
#
# Procesando Documento ID: 68f81b8800535f910a29f71a
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ANTONIO', Paterno: 'ROBLEDO', Materno: 'REYES'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f71a!
#
# Procesando Documento ID: 68f81b8800535f910a29f71b
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ANTONIO', Paterno: 'ROBLEDO', Materno: 'REYES'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f71b!
#
# Procesando Documento ID: 68f81b8800535f910a29f71c
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON AQUILES', Paterno: 'SANCHEZ', Materno: 'GUERRA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f71c!
#
# Procesando Documento ID: 68f81b8800535f910a29f71d
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ANTONIO', Paterno: 'ROBLEDO', Materno: 'REYES'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f71d!
#
# Procesando Documento ID: 68f81b8800535f910a29f71e
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ALFREDO', Paterno: 'RAMIREZ', Materno: 'BARAJAS'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f71e!
#
# Procesando Documento ID: 68f81b8800535f910a29f71f
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON AQUILES', Paterno: 'SANCHEZ', Materno: 'GUERRA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f71f!
#
# Procesando Documento ID: 68f81b8800535f910a29f720
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ARTURO', Paterno: 'GALVAN', Materno: 'RANGEL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f720!
#
# Procesando Documento ID: 68f81b8800535f910a29f721
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON AQUILES', Paterno: 'SANCHEZ', Materno: 'GUERRA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f721!
#
# Procesando Documento ID: 68f81b8800535f910a29f722
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ARTURO', Paterno: 'GALVAN', Materno: 'RANGEL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f722!
#
# Procesando Documento ID: 68f81b8800535f910a29f723
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ARTURO', Paterno: 'GALVAN', Materno: 'RANGEL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f723!
#
# Procesando Documento ID: 68f81b8800535f910a29f724
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON BISMARCK', Paterno: 'ACEVEDO', Materno: 'ROMO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f724!
#
# Procesando Documento ID: 68f81b8800535f910a29f725
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON ARTURO', Paterno: 'GALVAN', Materno: 'RANGEL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f725!
#
# Procesando Documento ID: 68f81b8800535f910a29f726
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON BISMARCK', Paterno: 'ACEVEDO', Materno: 'ROMO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f726!
#
# Procesando Documento ID: 68f81b8800535f910a29f727
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'AARON DANIEL', Paterno: 'SERRANO', Materno: 'GONZALEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a29f727!
#
# Procesando Documento ID: 68f81b8800535f910a29f728
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
# ...
#   > Nombre: 'ALAN', Paterno: 'MATA', Materno: 'ZUÑIGA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06cc!
#
# Procesando Documento ID: 68f81b8800535f910a2a06cd
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN', Paterno: 'LOERA', Materno: 'ESPARZA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06cd!
#
# Procesando Documento ID: 68f81b8800535f910a2a06ce
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN', Paterno: 'MATA', Materno: 'ZUÑIGA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06ce!
#
# Procesando Documento ID: 68f81b8800535f910a2a06cf
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN', Paterno: 'GUTIERREZ', Materno: 'RAMIREZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06cf!
#
# Procesando Documento ID: 68f81b8800535f910a2a06d0
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN', Paterno: 'CORREA', Materno: 'RAMIREZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06d0!
#
# Procesando Documento ID: 68f81b8800535f910a2a06d1
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN', Paterno: 'MATA', Materno: 'ZUÑIGA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06d1!
#
# Procesando Documento ID: 68f81b8800535f910a2a06d2
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN', Paterno: 'CORREA', Materno: 'RAMIREZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06d2!
#
# Procesando Documento ID: 68f81b8800535f910a2a06d3
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN AGUSTIN', Paterno: 'MONTALVO', Materno: 'DE LOREA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06d3!
#
# Procesando Documento ID: 68f81b8800535f910a2a06d4
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ABEL', Paterno: 'MOSQUEDA', Materno: 'AGUIÑAGA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06d4!
#
# Procesando Documento ID: 68f81b8800535f910a2a06d5
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ABEL', Paterno: 'MOSQUEDA', Materno: 'AGUIÑAGA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06d5!
#
# Procesando Documento ID: 68f81b8800535f910a2a06d6
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN AGUSTIN', Paterno: 'MONTALVO', Materno: 'DE LOREA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06d6!
#
# Procesando Documento ID: 68f81b8800535f910a2a06d7
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALBERTO', Paterno: 'HERNANDEZ', Materno: 'SANDOVAL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06d7!
#
# Procesando Documento ID: 68f81b8800535f910a2a06d8
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALBERTO', Paterno: 'PEREZ', Materno: 'VELASCO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06d8!
#
# Procesando Documento ID: 68f81b8800535f910a2a06d9
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALBERTO', Paterno: 'HERNANDEZ', Materno: 'SANDOVAL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06d9!
#
# Procesando Documento ID: 68f81b8800535f910a2a06da
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALBERTO', Paterno: 'PEREZ', Materno: 'VELASCO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06da!
#
# Procesando Documento ID: 68f81b8800535f910a2a06db
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALBERTO', Paterno: 'HERNANDEZ', Materno: 'SANDOVAL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06db!
#
# Procesando Documento ID: 68f81b8800535f910a2a06dc
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALBERTO', Paterno: 'DIAZ', Materno: 'ZUÑIGA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06dc!
#
# Procesando Documento ID: 68f81b8800535f910a2a06dd
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALBERTO', Paterno: 'PEREZ', Materno: 'VELASCO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06dd!
#
# Procesando Documento ID: 68f81b8800535f910a2a06de
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN AARON', Paterno: 'TAMAYO', Materno: 'VALADEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06de!
#
# Procesando Documento ID: 68f81b8800535f910a2a06df
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALBERTO', Paterno: 'HERNANDEZ', Materno: 'SANDOVAL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06df!
#
# Procesando Documento ID: 68f81b8800535f910a2a06e0
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALED', Paterno: 'PANIAGUA', Materno: 'FIGUEROA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06e0!
#
# Procesando Documento ID: 68f81b8800535f910a2a06e1
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALBERTO', Paterno: 'PEREZ', Materno: 'VELASCO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06e1!
#
# Procesando Documento ID: 68f81b8800535f910a2a06e2
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALEJANDRO', Paterno: 'SANCHEZ', Materno: 'ESPARZA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06e2!
#
# Procesando Documento ID: 68f81b8800535f910a2a06e3
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALEJANDRO', Paterno: 'LOPEZ', Materno: 'LOPEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06e3!
#
# Procesando Documento ID: 68f81b8800535f910a2a06e4
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALEJANDRO', Paterno: 'AGUILERA', Materno: 'RANGEL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06e4!
#
# Procesando Documento ID: 68f81b8800535f910a2a06e5
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALED', Paterno: 'PANIAGUA', Materno: 'FIGUEROA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06e5!
#
# Procesando Documento ID: 68f81b8800535f910a2a06e6
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALEJANDRO', Paterno: 'VALLE', Materno: 'ARENAS'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06e6!
#
# Procesando Documento ID: 68f81b8800535f910a2a06e7
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALEJANDRO', Paterno: 'LOPEZ', Materno: 'LOPEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06e7!
#
# Procesando Documento ID: 68f81b8800535f910a2a06e8
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALEJANDRO', Paterno: 'LOPEZ', Materno: 'LOPEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06e8!
#
# Procesando Documento ID: 68f81b8800535f910a2a06e9
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALEJANDRO', Paterno: 'RANGEL', Materno: 'DIAZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06e9!
#
# Procesando Documento ID: 68f81b8800535f910a2a06ea
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALEJANDRO', Paterno: 'VALLE', Materno: 'ARENAS'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06ea!
#
# Procesando Documento ID: 68f81b8800535f910a2a06eb
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALEJANDRO', Paterno: 'RANGEL', Materno: 'DIAZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06eb!
#
# Procesando Documento ID: 68f81b8800535f910a2a06ec
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALEJANDRO', Paterno: 'SANCHEZ', Materno: 'ESPARZA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06ec!
#
# Procesando Documento ID: 68f81b8800535f910a2a06ed
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALEJANDRO', Paterno: 'RAMIREZ', Materno: 'CALVILLO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06ed!
#
# Procesando Documento ID: 68f81b8800535f910a2a06ee
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALEJANDRO', Paterno: 'RAMIREZ', Materno: 'CALVILLO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06ee!
#
# Procesando Documento ID: 68f81b8800535f910a2a06ef
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALEJANDRO', Paterno: 'VALLE', Materno: 'ARENAS'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06ef!
#
# Procesando Documento ID: 68f81b8800535f910a2a06f0
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALEJANDRO', Paterno: 'AGUILERA', Materno: 'RANGEL'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06f0!
#
# Procesando Documento ID: 68f81b8800535f910a2a06f1
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALEJANDRO', Paterno: 'LOPEZ', Materno: 'LOPEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06f1!
#
# Procesando Documento ID: 68f81b8800535f910a2a06f2
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALEJANDRO', Paterno: 'RAMIREZ', Materno: 'CALVILLO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06f2!
#
# Procesando Documento ID: 68f81b8800535f910a2a06f3
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ALAN ALEJANDRO', Paterno: 'RAMIREZ', Materno: 'CALVILLO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a06f3!
#
# Procesando Documento ID: 68f81b8800535f910a2a01e3
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ADRIANA', Paterno: 'GNZALEZ', Materno: 'LOPEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a01e3!
#
# Procesando Documento ID: 68f81b8800535f910a2a01e4
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ADRIANA', Paterno: 'DAVALOS', Materno: 'REYES'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a01e4!
#
# Procesando Documento ID: 68f81b8800535f910a2a01e5
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ADRIANA', Paterno: 'FRAUSTO', Materno: 'GUTIERREZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a01e5!
#
# Procesando Documento ID: 68f81b8800535f910a2a01e6
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ADRIANA', Paterno: 'FLORES', Materno: 'VILLALOBOS'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a01e6!
#
# Procesando Documento ID: 68f81b8800535f910a2a01e7
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ADRIANA', Paterno: 'VALDES', Materno: 'MARTINEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a01e7!
#
# Procesando Documento ID: 68f81b8800535f910a2a01e8
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ADRIANA', Paterno: 'TRIANA', Materno: 'SALCE'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a01e8!
#
# Procesando Documento ID: 68f81b8800535f910a2a01e9
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ADRIANA', Paterno: 'FARIAS', Materno: 'MOLINA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a01e9!
#
# Procesando Documento ID: 68f81b8800535f910a2a01ea
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ADRIANA', Paterno: 'CASTAÑEDA', Materno: 'LOPEZ'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a01ea!
#
# Procesando Documento ID: 68f81b8800535f910a2a01eb
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ADRIANA', Paterno: 'VALDES', Materno: 'GARCIA'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
# ¡Resultado guardado/actualizado en 'metricas' para el ID: 68f81b8800535f910a2a01eb!
#
# Procesando Documento ID: 68f81b8800535f910a2a01ec
# --- RESULTADO DEL ANÁLISIS ---
#   > RFC Base: 'None'
#   > Nombre: 'ADRIANA', Paterno: 'GONZALEZ', Materno: 'ROMO'
#   > Resultado de la Métrica: SIN_DATO
# ---------------------------------
